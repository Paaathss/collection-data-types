# %% [markdown]
# Collection of data type is a container used to store multiple data items

# %% [markdown]
# # List

# %% [markdown]
# ordered sequence .
# mutable collection of data .
# theoritically of infinite length .
# iterable .
# allow duplicate members.
# return with square brackets.

# %%
list1 = ['fathima','nasrin',1234]
print(list1)
# Out:
# ['fathima', 'nasrin', 1234]

# %% [markdown]
# NESTED LIST

# %%
list = [['fathima',11],'path','helloo',1,23]
print(list)
# Out:
# [['fathima', 11], 'path', 'helloo', 1, 23]

# %% [markdown]
# # INDEXING

# %% [markdown]
# positive indexing and negative indexing

# %%
list = ['fathima','nasrin',123]
print(list[0])
# Out:
# fathima

# %%
print(list[-2])
# Out:
# nasrin

# %%
#SLICING

# %%
print(list[1:-1])
# Out:
# ['nasrin']

# %%
print(list[0:-2])
# Out:
# ['fathima']

# %%
print(list[1:-1])
print(list[-3:-1])
print(list[1:3])
# Out:
# ['nasrin']
# ['fathima', 'nasrin']
# ['nasrin', 123]

# %% [markdown]
# append

# %%
list = ['hi','hello',12]
list
# Out:
# ['hi', 'hello', 12]

# %%
list.append('world')
list
# Out:
# ['hi', 'hello', 12, 'world', 'world', 'world', 'world']

# %% [markdown]
# extend

# %%
list1 = ['fathma','hello']
list1
# Out:
# ['fathma', 'hello']

# %%
list1.extend('world')
list1
# Out:
# ['fathma', 'hello', 'w', 'o', 'r', 'l', 'd', 'w', 'o', 'r', 'l', 'd']

# %% [markdown]
# pop

# %%
list1.pop()
# Out:
# 'd'

# %% [markdown]
# remove

# %%
list1.remove('hello')

# %%
list1
# Out:
# ['fathma', 'o', 'r', 'l', 'd', 'w', 'o', 'r', 'l']

# %% [markdown]
# delete

# %%
del list1['fathima']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-d4cdcb55aad7> in <cell line: 1>()
# ----> 1 del list1['fathima']
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# count

# %%
list3 = [1,2,2,4,5,6]
list
# Out:
# ['hi', 'hello', 12, 'world', 'world', 'world', 'world']

# %%
list3.count(12)
# Out:
# 0

# %% [markdown]
# length

# %%
len(list3)
# Out:
# 6

# %%
min(list3)
# Out:
# 1

# %%
sum(list3)
# Out:
# 20

# %%
max(list3)
# Out:
# 6

# %% [markdown]
# sort(ascending,descending)

# %%
list4 = [56,3,8,77,9,100]
list4
# Out:
# [56, 3, 8, 77, 9, 100]

# %%
list4.sort(reverse = True)
list4
# Out:
# [100, 77, 56, 9, 8, 3]

# %%
list4.reverse()
list4
# Out:
# [3, 8, 9, 56, 77, 100]
